# %%
import pandas as pd

# %%
df=pd.read_csv("globalairquality.csv")

# %%
print(df)
# Out:
#                 City       Country        Date   PM2.5    PM10    NO2    SO2  \
# 0            Bangkok      Thailand  2023-03-19   86.57   25.19  99.88  30.63
# 1           Istanbul        Turkey  2023-02-16   50.63   97.39  48.14   8.71
# 2     Rio de Janeiro        Brazil  2023-11-13  130.21   57.22  98.51   9.92
# 3             Mumbai         India  2023-03-16  119.70  130.52  10.96  33.03
# 4              Paris        France  2023-04-04   55.20   36.62  76.85  21.85
# ...              ...           ...         ...     ...     ...    ...    ...
# 9995    Johannesburg  South Africa  2023-09-16  147.85  184.34  90.33  34.93
# 9996          Berlin       Germany  2023-12-05   12.22  121.49  49.04   5.66
# 9997          Moscow        Russia  2023-11-26   44.07  143.62   8.41  32.58
# 9998          Berlin       Germany  2023-02-03   67.43   96.79  43.23  29.19
# 9999         Bangkok      Thailand  2023-06-13   16.34   28.80  50.48  21.20
#
# ...

# %%
df
# Out:
#                 City       Country        Date   PM2.5    PM10    NO2    SO2  \
# 0            Bangkok      Thailand  2023-03-19   86.57   25.19  99.88  30.63
# 1           Istanbul        Turkey  2023-02-16   50.63   97.39  48.14   8.71
# 2     Rio de Janeiro        Brazil  2023-11-13  130.21   57.22  98.51   9.92
# 3             Mumbai         India  2023-03-16  119.70  130.52  10.96  33.03
# 4              Paris        France  2023-04-04   55.20   36.62  76.85  21.85
# ...              ...           ...         ...     ...     ...    ...    ...
# 9995    Johannesburg  South Africa  2023-09-16  147.85  184.34  90.33  34.93
# 9996          Berlin       Germany  2023-12-05   12.22  121.49  49.04   5.66
# 9997          Moscow        Russia  2023-11-26   44.07  143.62   8.41  32.58
# 9998          Berlin       Germany  2023-02-03   67.43   96.79  43.23  29.19
# 9999         Bangkok      Thailand  2023-06-13   16.34   28.80  50.48  21.20
#
# ...

# %%
#selecting the data

# %%
df["Country"]
# Out:
# 0           Thailand
# 1             Turkey
# 2             Brazil
# 3              India
# 4             France
#             ...
# 9995    South Africa
# 9996         Germany
# 9997          Russia
# 9998         Germany
# 9999        Thailand
# Name: Country, Length: 10000, dtype: object

# %%
df["City"]
# Out:
# 0              Bangkok
# 1             Istanbul
# 2       Rio de Janeiro
# 3               Mumbai
# 4                Paris
#              ...
# 9995      Johannesburg
# 9996            Berlin
# 9997            Moscow
# 9998            Berlin
# 9999           Bangkok
# Name: City, Length: 10000, dtype: object

# %%
#selecting multiple columns

# %%
df[["Country","Temperature"]]
# Out:
#            Country  Temperature
# 0         Thailand        17.67
# 1           Turkey         3.46
# 2           Brazil        25.29
# 3            India        23.15
# 4           France        16.02
# ...            ...          ...
# 9995  South Africa        -1.92
# 9996       Germany        -9.81
# 9997        Russia        39.35
# 9998       Germany        26.21
# 9999      Thailand         2.50
#
# [10000 rows x 2 columns]

# %%
df.loc[2]
# Out:
# City           Rio de Janeiro
# Country                Brazil
# Date               2023-11-13
# PM2.5                  130.21
# PM10                    57.22
# NO2                     98.51
# SO2                      9.92
# CO                       0.12
# O3                     179.31
# Temperature             25.29
# Humidity                 29.3
# Wind Speed              12.87
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# City           Rio de Janeiro
# Country                Brazil
# Date               2023-11-13
# PM2.5                  130.21
# PM10                    57.22
# NO2                     98.51
# SO2                      9.92
# CO                       0.12
# O3                     179.31
# Temperature             25.29
# Humidity                 29.3
# Wind Speed              12.87
# Name: 2, dtype: object

# %%
df.iloc[1:3]
# Out:
#              City Country        Date   PM2.5   PM10    NO2   SO2    CO  \
# 1        Istanbul  Turkey  2023-02-16   50.63  97.39  48.14  8.71  3.40
# 2  Rio de Janeiro  Brazil  2023-11-13  130.21  57.22  98.51  9.92  0.12
#
#        O3  Temperature  Humidity  Wind Speed
# 1  144.16         3.46     67.51        6.36
# 2  179.31        25.29     29.30       12.87

# %%
df.loc[1:3]
# Out:
#              City Country        Date   PM2.5    PM10    NO2    SO2    CO  \
# 1        Istanbul  Turkey  2023-02-16   50.63   97.39  48.14   8.71  3.40
# 2  Rio de Janeiro  Brazil  2023-11-13  130.21   57.22  98.51   9.92  0.12
# 3          Mumbai   India  2023-03-16  119.70  130.52  10.96  33.03  7.74
#
#        O3  Temperature  Humidity  Wind Speed
# 1  144.16         3.46     67.51        6.36
# 2  179.31        25.29     29.30       12.87
# 3   38.65        23.15     99.97        7.71

# %%
#both rows and columns i.e, individual cell

# %%
df.loc[0:2,["Temperature","City"]]
# Out:
#    Temperature            City
# 0        17.67         Bangkok
# 1         3.46        Istanbul
# 2        25.29  Rio de Janeiro

# %%
df.columns
# Out:
# Index(['City', 'Country', 'Date', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3',
#        'Temperature', 'Humidity', 'Wind Speed'],
#       dtype='object')

# %%
df.iloc[0:2,1]
# Out:
# 0    Thailand
# 1      Turkey
# Name: Country, dtype: object

# %%
df.iloc[0:2,1:2]
# Out:
#     Country
# 0  Thailand
# 1    Turkey

# %%
#selecting single scalar value

# %%
df.at[0,"City"]
# Out:
# 'Bangkok'

# %%
df.at[1,"City"]
# Out:
# 'Istanbul'

# %%
df.columns
# Out:
# Index(['City', 'Country', 'Date', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3',
#        'Temperature', 'Humidity', 'Wind Speed'],
#       dtype='object')

# %%
df.iat[0,0]
# Out:
# 'Bangkok'

# %%
df.iat[1,1]
# Out:
# 'Turkey'

# %%
#copy and view

# %%
cities=df["City"].copy()

# %%
cities[0]="Vizag"

# %%
df["City"]
# Out:
# 0                Vizag
# 1             Istanbul
# 2       Rio de Janeiro
# 3               Mumbai
# 4                Paris
#              ...
# 9995      Johannesburg
# 9996            Berlin
# 9997            Moscow
# 9998            Berlin
# 9999           Bangkok
# Name: City, Length: 10000, dtype: object

# %%
df["City"]
# Out:
# 0                Vizag
# 1             Istanbul
# 2       Rio de Janeiro
# 3               Mumbai
# 4                Paris
#              ...
# 9995      Johannesburg
# 9996            Berlin
# 9997            Moscow
# 9998            Berlin
# 9999           Bangkok
# Name: City, Length: 10000, dtype: object

# %%
df
# Out:
#                 City       Country        Date   PM2.5    PM10    NO2    SO2  \
# 0              Vizag      Thailand  2023-03-19   86.57   25.19  99.88  30.63
# 1           Istanbul        Turkey  2023-02-16   50.63   97.39  48.14   8.71
# 2     Rio de Janeiro        Brazil  2023-11-13  130.21   57.22  98.51   9.92
# 3             Mumbai         India  2023-03-16  119.70  130.52  10.96  33.03
# 4              Paris        France  2023-04-04   55.20   36.62  76.85  21.85
# ...              ...           ...         ...     ...     ...    ...    ...
# 9995    Johannesburg  South Africa  2023-09-16  147.85  184.34  90.33  34.93
# 9996          Berlin       Germany  2023-12-05   12.22  121.49  49.04   5.66
# 9997          Moscow        Russia  2023-11-26   44.07  143.62   8.41  32.58
# 9998          Berlin       Germany  2023-02-03   67.43   96.79  43.23  29.19
# 9999         Bangkok      Thailand  2023-06-13   16.34   28.80  50.48  21.20
#
# ...

# %%
cities
# Out:
# 0                Vizag
# 1             Istanbul
# 2       Rio de Janeiro
# 3               Mumbai
# 4                Paris
#              ...
# 9995      Johannesburg
# 9996            Berlin
# 9997            Moscow
# 9998            Berlin
# 9999           Bangkok
# Name: City, Length: 10000, dtype: object

# %%
df
# Out:
#                 City       Country        Date   PM2.5    PM10    NO2    SO2  \
# 0              Vizag      Thailand  2023-03-19   86.57   25.19  99.88  30.63
# 1           Istanbul        Turkey  2023-02-16   50.63   97.39  48.14   8.71
# 2     Rio de Janeiro        Brazil  2023-11-13  130.21   57.22  98.51   9.92
# 3             Mumbai         India  2023-03-16  119.70  130.52  10.96  33.03
# 4              Paris        France  2023-04-04   55.20   36.62  76.85  21.85
# ...              ...           ...         ...     ...     ...    ...    ...
# 9995    Johannesburg  South Africa  2023-09-16  147.85  184.34  90.33  34.93
# 9996          Berlin       Germany  2023-12-05   12.22  121.49  49.04   5.66
# 9997          Moscow        Russia  2023-11-26   44.07  143.62   8.41  32.58
# 9998          Berlin       Germany  2023-02-03   67.43   96.79  43.23  29.19
# 9999         Bangkok      Thailand  2023-06-13   16.34   28.80  50.48  21.20
#
# ...

# %%
citie=df["City"]

# %%
citie[0]="Bangkok"
# Out:
# C:\Users\Varas\AppData\Local\Temp\ipykernel_32416\2793584325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citie[0]="Bangkok"

# %%
df
# Out:
#                 City       Country        Date   PM2.5    PM10    NO2    SO2  \
# 0            Bangkok      Thailand  2023-03-19   86.57   25.19  99.88  30.63
# 1           Istanbul        Turkey  2023-02-16   50.63   97.39  48.14   8.71
# 2     Rio de Janeiro        Brazil  2023-11-13  130.21   57.22  98.51   9.92
# 3             Mumbai         India  2023-03-16  119.70  130.52  10.96  33.03
# 4              Paris        France  2023-04-04   55.20   36.62  76.85  21.85
# ...              ...           ...         ...     ...     ...    ...    ...
# 9995    Johannesburg  South Africa  2023-09-16  147.85  184.34  90.33  34.93
# 9996          Berlin       Germany  2023-12-05   12.22  121.49  49.04   5.66
# 9997          Moscow        Russia  2023-11-26   44.07  143.62   8.41  32.58
# 9998          Berlin       Germany  2023-02-03   67.43   96.79  43.23  29.19
# 9999         Bangkok      Thailand  2023-06-13   16.34   28.80  50.48  21.20
#
# ...
